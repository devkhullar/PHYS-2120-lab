# %% [markdown]
# ## I am going to do redo everything

# %%
import numpy as np
import matplotlib.pyplot as plt

import scienceplots 
plt.style.use(['science','notebook', 'grid'])

from matplotlib import rc
rc('text', usetex=True)
font = {'family' : 'serif',
        'weight' : 'bold',
        'size'   : '14'}
rc('font', **font)

# %%
x_cm = np.array([-0.456, 0.8505, 2.1025, 3.464, 4.879, 6.185, 7.655, 9.125])
x_a = np.array([-4.484, -2.307, 0.088, 2.593, 5.206, 7.927, 10.431, 13.044])
x_b = np.array([3.572, 4.008, 4.117, 4.335, 4.552, 4.443, 4.879, 5.206])
time = np.array([0, 0.033333333, 0.066666667, 0.1, 0.133333333, 0.166666667, 0.2, 0.233333333])

# %%
plt.plot(time, x_cm, 'o--', label='$x_{cm}$', markersize = 5)
plt.plot(time, x_a, 's', label='$x_A$', markersize = 5)
plt.plot(time, x_b, 'v', label='$x_B$', markersize = 5)
plt.xlabel("Time [s]")
plt.ylabel("Position [cm]")
plt.text(0.15, 2.5, "$y = 40.983x - 0.5557$", fontsize='large')
plt.legend()
plt.savefig("p.vs.t_part1.png")

# %%
time_run4 = np.array([0 ,0.05 ,0.1 ,0.15 ,0.2 ,0.25 ,0.3 ,0.35 ,0.4 ,0.45 ,0.5 ,0.55 ,0.6, 0.65])
p_run4 = np.array([0.216, 0.241, 0.271, 0.304, 0.341, 0.381, 0.425, 0.472, 0.523, 0.577, 0.636, 0.699, 0.765, 0.834])
error_run4 = np.array([0.000524238, 0.000524238, 0.000524238, 0.000524238, 0.000524238, 0.000524238, 
           0.000524238, 0.000524238, 0.000524238, 0.000524238, 0.000524238, 0.000524238, 
           0.000524238, 0.000524238]) 
time_run7 = np.array([0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75])
p_run7 = np.array([0.208, 0.228, 0.251, 0.277, 0.307, 0.339, 0.374, 0.411, 0.452, 0.496, 0.543, 0.592, 0.644, 0.7, 0.757, 0.813])
error_run7 = np.array([0.001232313, 0.001232313, 0.001232313, 0.001232313, 0.001232313, 0.001232313, 
           0.001232313, 0.001232313, 0.001232313, 0.001232313, 0.001232313, 0.001232313, 
           0.001232313, 0.001232313, 0.001232313, 0.001232313])

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(time_run4, p_run4, 'o--', label='Disk')
ax.plot(time_run7, p_run7, 'v--', label='Ring')
# plt.text(0.45, 0.4, "$0.7302x^2+0.476-0.216$", color='b')
# plt.text(0.45, 0.2, "$0.5661x^2+0.3877x+0.2069$", color='g')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Position [cm]')
# bbox=dict(facecolor='white', edgecolor='black')
ax.text(0.65, 0.4, '$0.7302x^2+0.476-0.216$', transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='blue'))
ax.text(0.60, 0.2, '$0.5661x^2+0.3877x+0.2069$', transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='green'))
ax.legend()
plt.ylim(0)
plt.savefig('position.vs.time_part2.png')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,5))
ax.plot(time_run4, p_run4, 'o--', label='Disk')
ax.plot(time_run7, p_run7, 'v--', label='Ring')
plt.text(0.45, 0.4, "$0.7302x^2+0.476-0.216$", color='b')
plt.text(0.45, 0.3, "$0.5661x^2+0.3877x+0.2069$", color='g')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Position [m]')
# bbox=dict(facecolor='white', edgecolor='black')
# ax.text(0.65, 0.4, '$0.7302x^2+0.476-0.216$', transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='blue'))
# ax.text(0.60, 0.3, '$0.5661x^2+0.3877x+0.2069$', transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='green'))
# ax.legend()
# plt.savefig('part2.png') 
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(time_run4, p_run4, 'o--', label='Disk', color='blue')
plt.errorbar(time_run4, p_run4, yerr = error_run4, ecolor = 'k',capsize = 3, ls = '--')
ax.plot(time_run7, p_run7, 'v--', label='Ring', color='green')
plt.errorbar(time_run7, p_run7, yerr = error_run7, ecolor = 'k',capsize = 3, ls = '--')
# plt.text(0.45, 0.4, "$0.7302x^2+0.476-0.216$", color='b')
# plt.text(0.45, 0.2, "$0.5661x^2+0.3877x+0.2069$", color='g')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Position [m]')
# bbox=dict(facecolor='white', edgecolor='black')
ax.text(0.65, 0.4, '$0.7302x^2+0.476-0.216$', transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='blue'))
ax.text(0.60, 0.2, '$0.5661x^2+0.3877x+0.2069$', transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='green'))
plt.ylim(0)
ax.legend()
# plt.savefig('part3.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 fig, ax = plt.subplots(nrows=1, ncols=1)
# ----> 2 ax.plot(time_run4, p_run4, 'o--', label='Disk', color='blue')
#       3 plt.errorbar(time_run4, p_run4, yerr = error_run4, ecolor = 'k',capsize = 3, ls = '--')
#       4 ax.plot(time_run7, p_run7, 'v--', label='Ring', color='green')
#
# NameError: name 'time_run4' is not defined

# %%
x_a_A = np.array([-4.484, -2.307, 0.088, 2.593, 5.206, 7.927, 10.431, 13.044])
y_a_A = np.array([10.3, 11.171, 11.716, 11.934, 12.042, 11.825, 11.389, 10.518])

x_b_B = np.array([3.572, 4.008, 4.117, 4.335, 4.552, 4.443, 4.879, 5.206])
y_b_B = np.array([2.135, 1.264, 0.72, 0.502, 0.284, 0.611, 1.264, 1.917])

x_cm = np.array([-0.456, 0.8505, 2.1025, 3.464, 4.879, 6.185, 7.655, 9.125])
y_cm = np.array([6.218, 6.218, 6.218, 6.218, 6.163, 6.218, 6.327, 6.218])

x_theo_1 = np.array([-4.484, -2.003, 0.624, 3.335, 6.062, 8.736, 11.290, 13.665])
y_theo_1 = np.array([10.599, 11.384, 11.901, 12.122, 12.038, 11.652, 10.983, 10.066])

x_theo_2 = np.array([4.005, 4.340, 4.502, 4.552, 4.556, 4.583, 4.700, 4.971])
y_theo_2 = np.array([1.956, 1.063, 0.423, 0.069, 0.017, 0.271, 0.817, 1.629])

time = np.array([0, 0.033333333, 0.066666667, 0.1, 0.133333333, 0.166666667, 0.2, 0.233333333])

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(x_a_A, y_a_A, 'o--', label='$y_{A,exp}$ vs $x_{A,exp}$')
ax.plot(x_b_B, y_b_B, 'v--', label='$y_{B,exp}$ vs $x_{B,exp}$' )  #label="$y_{B, exp}$ vs $x_{B,exp}
ax.plot(x_cm, y_cm, '^--', label='$y_{cm}$ vs $x_{cm}$')
ax.plot(x_theo_1, y_theo_1, '+--', label='$y_{A,cyc}$ vs $x_{A,cyc}$')
ax.plot(x_theo_2, y_theo_2, 'x--', label='$y_{B,cyc}$ vs $x_{B,cyc}$')
ax.set_xlabel('$x$-position [cm]')
ax.set_ylabel('$y$-position [cm]')
ax.legend()
plt.savefig('y_vs_x_par1_updated.png')
